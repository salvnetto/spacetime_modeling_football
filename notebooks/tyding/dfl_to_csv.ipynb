# %%
from kloppy import sportec
import pandas as pd
from pathlib import Path

match_ids = [
    "000001_DFL-MAT-J03WMX",
    "000001_DFL-MAT-J03WN1",
    "000002_DFL-MAT-J03WOH",
    "000002_DFL-MAT-J03WOY",
    "000002_DFL-MAT-J03WPY",
    "000002_DFL-MAT-J03WQQ",
    "000002_DFL-MAT-J03WR9"
]

data_dir = Path("data/dfl/raw")
output_dir = Path("data/dfl")

for match_id in match_ids:
    # Load event data
    events = sportec.load_event(
        event_data=data_dir / f"DFL_03_02_events_raw_DFL-COM-{match_id}.xml",
        meta_data=data_dir / f"DFL_02_01_matchinformation_DFL-COM-{match_id}.xml",
        coordinates = "metrica"
    )

    # Load tracking data
    tracking = sportec.load_tracking(
        raw_data=data_dir / f"DFL_04_03_positions_raw_observed_DFL-COM-{match_id}.xml",
        meta_data=data_dir / f"DFL_02_01_matchinformation_DFL-COM-{match_id}.xml",
        only_alive=False,
        coordinates = "metrica"
    )

    # Convert to DataFrame
    events_df = events.to_df()
    events_df["time_seconds"] = events_df["timestamp"].dt.total_seconds()
    tracking_df = tracking.to_df()
    tracking_df["time_seconds"] = tracking_df["timestamp"].dt.total_seconds()

    # Save
    events_df.to_csv(output_dir / f"{match_id}_events.csv", index=False)
    tracking_df.to_csv(output_dir / f"{match_id}_tracking.csv", index=False)

    print(f"Saved {match_id}")
# Out:
# Saved 000001_DFL-MAT-J03WMX

# %%
tracking_df
# Out:
#         period_id              timestamp  frame_id ball_state  \
# 0               1        0 days 00:00:00     10000      alive
# 1               1 0 days 00:00:00.040000     10001      alive
# 2               1 0 days 00:00:00.080000     10002      alive
# 3               1 0 days 00:00:00.120000     10003      alive
# 4               1 0 days 00:00:00.160000     10004      alive
# ...           ...                    ...       ...        ...
# 145962          2 0 days 00:50:10.160000    175254       dead
# 145963          2 0 days 00:50:10.200000    175255       dead
# 145964          2 0 days 00:50:10.240000    175256       dead
# 145965          2 0 days 00:50:10.280000    175257       dead
# 145966          2 0 days 00:50:10.320000    175258       dead
#
#        ball_owning_team_id    ball_x    ball_y  ball_z  ball_speed  \
# 0           DFL-CLU-00000G  0.501714  0.502500    0.00        1.98
# 1           DFL-CLU-00000G  0.496190  0.502794    0.00        2.02
# 2           DFL-CLU-00000G  0.490762  0.503088    0.01        2.02
# 3           DFL-CLU-00000G  0.485333  0.503529    0.01        2.02
# 4           DFL-CLU-00000G  0.479810  0.503824    0.02        2.02
# ...                    ...       ...       ...     ...         ...
# 145962      DFL-CLU-00000G  0.547143  0.325882    0.00       42.80
# 145963      DFL-CLU-00000G  0.547143  0.325882    0.00       42.80
# 145964      DFL-CLU-00000G  0.547143  0.325882    0.00       42.80
# 145965      DFL-CLU-00000G  0.547143  0.325882    0.00       42.80
# 145966      DFL-CLU-00000G  0.547143  0.325882    0.00       42.80
#
#         DFL-OBJ-0002DR_x  ...  DFL-OBJ-002GBW_d DFL-OBJ-002GBW_s  \
# 0               0.054952  ...              None              NaN
# 1               0.055143  ...              None              NaN
# 2               0.055429  ...              None              NaN
# 3               0.055714  ...              None              NaN
# 4               0.056000  ...              None              NaN
# ...                  ...  ...               ...              ...
# 145962          0.791905  ...              None             3.81
# 145963          0.791238  ...              None             3.83
# 145964          0.790571  ...              None             3.85
# 145965          0.790000  ...              None             3.86
# 145966          0.789238  ...              None             3.88
#
#         DFL-OBJ-J01N65_x  DFL-OBJ-J01N65_y  DFL-OBJ-J01N65_d DFL-OBJ-J01N65_s  \
# 0                    NaN               NaN              None              NaN
# 1                    NaN               NaN              None              NaN
# 2                    NaN               NaN              None              NaN
# 3                    NaN               NaN              None              NaN
# 4                    NaN               NaN              None              NaN
# ...                  ...               ...               ...              ...
# 145962          0.380286          0.544412              None             0.01
# 145963          0.380286          0.544412              None             0.01
# 145964          0.380286          0.544412              None             0.01
# 145965          0.380286          0.544412              None             0.01
# 145966          0.380286          0.544412              None             0.01
#
#         DFL-OBJ-002GCR_x  DFL-OBJ-002GCR_y  DFL-OBJ-002GCR_d DFL-OBJ-002GCR_s
# 0                    NaN               NaN              None              NaN
# 1                    NaN               NaN              None              NaN
# 2                    NaN               NaN              None              NaN
# 3                    NaN               NaN              None              NaN
# 4                    NaN               NaN              None              NaN
# ...                  ...               ...               ...              ...
# 145962          0.516095          0.605441              None             4.95
# 145963          0.515524          0.605294              None             4.89
# 145964          0.515048          0.605294              None             4.77
# 145965          0.514571          0.605147              None             4.61
# 145966          0.514095          0.605147              None             4.41
#
# [145967 rows x 137 columns]
